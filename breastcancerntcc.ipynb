# %% [markdown]
# <a href="https://colab.research.google.com/github/yusratariqq/Calculator/blob/main/breastcancerntcc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd

# Load dataset
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target

# Check data
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
print(df.shape)
print(df['target'].value_counts())  # 0 = malignant, 1 = benign
df.describe()
# Out:
# (569, 31)
# target
# 1    357
# 0    212
# Name: count, dtype: int64
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# ...

# %%
from sklearn.preprocessing import StandardScaler

X = df.drop('target', axis=1)
y = df['target']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

model = LogisticRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96        43
#            1       0.97      0.99      0.98        71
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

nn_model = Sequential([
    Dense(30, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(15, activation='relu'),
    Dense(1, activation='sigmoid')
])

nn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
nn_model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.6749 - loss: 0.6282 - val_accuracy: 0.7912 - val_loss: 0.5078
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8051 - loss: 0.4890 - val_accuracy: 0.9121 - val_loss: 0.3883
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9379 - loss: 0.3716 - val_accuracy: 0.9231 - val_loss: 0.3088
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9285 - loss: 0.3098 - val_accuracy: 0.9560 - val_loss: 0.2536
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9465 - loss: 0.2303 - val_accuracy: 0.9670 - val_loss: 0.2129
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9668 - loss: 0.1803 - val_accuracy: 0.9670 - val_loss: 0.1833
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9564 - loss: 0.1687 - val_accuracy: 0.9780 - val_loss: 0.1632
# Epoch 8/50
# ...

# %%
loss, accuracy = nn_model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9645 - loss: 0.1034
# Test Accuracy: 0.97

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation heatmap
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(), cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


model = Sequential([
    Dense(30, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(15, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# This will create the `history` object
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.6248 - loss: 0.6298 - val_accuracy: 0.8132 - val_loss: 0.5048
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7894 - loss: 0.5143 - val_accuracy: 0.9011 - val_loss: 0.3911
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8977 - loss: 0.3851 - val_accuracy: 0.9231 - val_loss: 0.3107
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9531 - loss: 0.2947 - val_accuracy: 0.9451 - val_loss: 0.2451
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9471 - loss: 0.2431 - val_accuracy: 0.9560 - val_loss: 0.2013
# ...

# %%
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title("Training vs Validation Accuracy")
plt.show()

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title("Training vs Validation Loss")
plt.show()

# %% [markdown]
# **Predict Cancer from New Patient Feature Values**

# %%
import numpy as np

# 👇 STEP 1: Plugging new patient's 30 features in the same order as the training data
new_patient_data = np.array([[18.2, 11.6, 120.5, 1000.0, 0.118, 0.277, 0.300, 0.150, 0.200, 0.060,
                              0.500, 1.200, 3.500, 50.0, 0.006, 0.050, 0.060, 0.020, 0.020, 0.005,
                              20.0, 18.0, 130.0, 1500.0, 0.140, 0.460, 0.450, 0.190, 0.250, 0.070]])

# 👇 STEP 2: Scaling the data using the same scaler used during training
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
new_patient_scaled = scaler.transform(new_patient_data)

# 👇 STEP 3: Predicting using our trained model
prediction = model.predict(new_patient_scaled)

# 👇 STEP 4: Interpret the result
if prediction >= 0.5:
    print(f"🔴 Cancer Detected (Malignant) — Confidence: {prediction[0][0]:.2f}")
else:
    print(f"🟢 No Cancer (Benign) — Confidence: {1 - prediction[0][0]:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 🟢 No Cancer (Benign) — Confidence: 1.00
